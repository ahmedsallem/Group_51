# %%
import pandas as pd

# %%
df= pd.read_csv("CarPrice_Assignment.csv")

# %%
df.head(3)
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
#
#        carbody drivewheel enginelocation  wheelbase  ...  fuelsystem  \
# 0  convertible        rwd          front       88.6  ...        mpfi
# 1  convertible        rwd          front       88.6  ...        mpfi
# 2    hatchback        rwd          front       94.5  ...        mpfi
#
#    boreratio  stroke  compressionratio horsepower peakrpm  citympg highwaympg  \
# 0       3.47    2.68               9.0        111    5000       21         27
# 1       3.47    2.68               9.0        111    5000       21         27
# 2       2.68    3.47               9.0        154    5000       19         26
#
#      price  highwaympg.1
# 0  13495.0            27
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
num_cols = df.select_dtypes(["int" , "float"]).columns
num_cols
# Out:
# Index(['car_ID', 'symboling', 'wheelbase', 'carlength', 'carwidth',
#        'carheight', 'curbweight', 'enginesize', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price', 'highwaympg.1'],
#       dtype='object')

# %%
obj_col = df.select_dtypes("object").columns
obj_col
# Out:
# Index(['CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody',
#        'drivewheel', 'enginelocation', 'enginetype', 'cylindernumber',
#        'fuelsystem'],
#       dtype='object')

# %%
df[obj_col].describe()
# Out:
#               CarName fueltype aspiration doornumber carbody drivewheel  \
# count             205      205        205        205     205        205
# unique            147        2          2          2       5          3
# top     toyota corona      gas        std       four   sedan        fwd
# freq                6      185        168        115      96        120
#
#        enginelocation enginetype cylindernumber fuelsystem
# count             205        205            205        205
# unique              2          7              7          8
# top             front        ohc           four       mpfi
# freq              202        148            159         94

# %%
filt = "fueltype == 'gas' and price >= 15000 and doornumber == 'two'"
df.query(filt)
# Out:
#      car_ID  symboling                          CarName fueltype aspiration  \
# 1         2          3              alfa-romero stelvio      gas        std
# 2         3          1         alfa-romero Quadrifoglio      gas        std
# 5         6          2                         audi fox      gas        std
# 9        10          0              audi 5000s (diesel)      gas      turbo
# 10       11          2                         bmw 320i      gas        std
# 12       13          0                           bmw x1      gas        std
# 16       17          0                           bmw x5      gas        std
# 49       50          0                        jaguar xk      gas        std
# 58       59          3                      mazda glc 4      gas        std
# 72       73          3                    buick skylark      gas        std
# 74       75          1  buick regal sport coupe (turbo)      gas        std
# ...

# %%
df[["fueltype" , "price"]]
# Out:
#     fueltype    price
# 0        gas  13495.0
# 1        gas  16500.0
# 2        gas  16500.0
# 3        gas  13950.0
# 4        gas  17450.0
# ..       ...      ...
# 200      gas  16845.0
# 201      gas  19045.0
# 202      gas  21485.0
# 203   diesel  22470.0
# 204      gas  22625.0
#
# [205 rows x 2 columns]

# %%
df["price"].max()
# Out:
# 45400.0

# %%
df.query("fueltype == 'gas'")["price"].max()
# Out:
# 45400.0

# %%
df.query("fueltype == 'diesel'")["price"].max()
# Out:
# 31600.0

# %%
df[["fueltype" , "price"]].groupby("fueltype").max()
# Out:
#             price
# fueltype
# diesel    31600.0
# gas       45400.0

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price', 'highwaympg.1'],
#       dtype='object')

# %%
df[["enginelocation" , "price"]].groupby("enginelocation").max()
# Out:
#                   price
# enginelocation
# front           45400.0
# rear            37028.0

# %%
df["doornumber"].unique()
# Out:
# array(['two', 'four'], dtype=object)

# %%
df["doornumber"] = df["doornumber"].replace({"two" : 2 , "four" : 4})

# %%
df["cylindernumber"].value_counts()
# Out:
# four      159
# six        24
# five       11
# eight       5
# two         4
# three       1
# twelve      1
# Name: cylindernumber, dtype: int64

# %%
df["cylindernumber"].value_counts().index
# Out:
# Index(['four', 'six', 'five', 'eight', 'two', 'three', 'twelve'], dtype='object')

# %%
df["cylindernumber"].value_counts().values
# Out:
# array([159,  24,  11,   5,   4,   1,   1], dtype=int64)

# %%
# pd.get_dummies(df[["cylindernumber"]])

# %%
# !pip install word2number

# %%
from word2number import w2n

# %%
w2n.word_to_num("five")
# Out:
# 5

# %%
try:
    df["cylindernumber"] = df["cylindernumber"].apply(w2n.word_to_num)
except Exception as e:
    print(f"Erorr: {e}")
# Out:
# Erorr: Type of input is not string! Please enter a valid number word (eg. 'two million twenty three thousand and forty nine')
# AMIT

# %%
try:
    df["cylindernumber"] = df["cylindernumber"].apply(w2n.word_to_num)
except Exception as e:
    print("Error:",e)
print("amit")
# Out:
# Error: Type of input is not string! Please enter a valid number word (eg. 'two million twenty three thousand and forty nine')
# amit

# %%
# df["enginelocation"]
from sklearn.preprocessing import LabelEncoder
 
label_encoder = LabelEncoder() 
  
df['enginelocation_encoded']= label_encoder.fit_transform(df['enginelocation']) 
  
# df['enginelocation_encoded'].unique()

# %%
df[[ "enginelocation", 'enginelocation_encoded']]
# Out:
#     enginelocation  enginelocation_encoded
# 0            front                       0
# 1            front                       0
# 2            front                       0
# 3            front                       0
# 4            front                       0
# ..             ...                     ...
# 200          front                       0
# 201          front                       0
# 202          front                       0
# 203          front                       0
# 204          front                       0
#
# [205 rows x 2 columns]

# %%
df = pd.get_dummies(df , columns=["enginelocation"])

# %%
df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#      doornumber      carbody drivewheel  wheelbase  carlength  ...  \
# 0             2  convertible        rwd       88.6      168.8  ...
# ...

# %%
try:
    df = df.drop("highwaympg.1" , axis=1)
except Exception as e :
    print(f"Error: {e}")
# Out:
# Error: "['highwaympg.1'] not found in axis"

# %%
df["CarName"] = df["CarName"].str.split(expand = True)[0]

# %%
df["CarName"].value_counts()
# Out:
# toyota         31
# nissan         17
# mazda          15
# honda          13
# mitsubishi     13
# subaru         12
# peugeot        11
# volvo          11
# volkswagen      9
# dodge           9
# buick           8
# bmw             8
# audi            7
# plymouth        7
# saab            6
# isuzu           4
# porsche         4
# alfa-romero     3
# chevrolet       3
# jaguar          3
# vw              2
# maxda           2
# renault         2
# toyouta         1
# vokswagen       1
# Nissan          1
# mercury         1
# porcshce        1
# Name: CarName, dtype: int64

# %%
df["CarName"] = df["CarName"].str.lower()

# %%
df["CarName"].value_counts()
# Out:
# toyota         31
# nissan         18
# mazda          15
# honda          13
# mitsubishi     13
# subaru         12
# peugeot        11
# volvo          11
# dodge           9
# volkswagen      9
# bmw             8
# buick           8
# audi            7
# plymouth        7
# saab            6
# isuzu           4
# porsche         4
# alfa-romero     3
# jaguar          3
# chevrolet       3
# vw              2
# maxda           2
# renault         2
# toyouta         1
# vokswagen       1
# mercury         1
# porcshce        1
# Name: CarName, dtype: int64

# %%
df[df["CarName"] == "gas"]
# Out:
# Empty DataFrame
# Columns: [car_ID, symboling, CarName, fueltype, aspiration, doornumber, carbody, drivewheel, wheelbase, carlength, carwidth, carheight, curbweight, enginetype, cylindernumber, enginesize, fuelsystem, boreratio, stroke, compressionratio, horsepower, peakrpm, citympg, highwaympg, price, enginelocation_encoded, enginelocation_front, enginelocation_rear]
# Index: []
#
# [0 rows x 28 columns]

# %%
df[["fueltype" , "CarName"]].groupby("CarName").agg(lambda x : x.mode())
# Out:
#                   fueltype
# CarName
# alfa-romero            gas
# audi                   gas
# bmw                    gas
# buick        [diesel, gas]
# chevrolet              gas
# dodge                  gas
# honda                  gas
# isuzu                  gas
# jaguar                 gas
# maxda                  gas
# mazda                  gas
# mercury                gas
# mitsubishi             gas
# nissan                 gas
# peugeot                gas
# plymouth               gas
# porcshce               gas
# porsche                gas
# renault                gas
# saab                   gas
# subaru                 gas
# toyota                 gas
# toyouta                gas
# vokswagen           diesel
# volkswagen             gas
# volvo                  gas
# vw                     gas

# %%
import numpy as np
df = pd.DataFrame({"name": ["A" , "B" , "C" , "D" , "E"] , "age":[23,24,22,np.nan , 25] })

# %%
df
# Out:
#   name   age
# 0    A  23.0
# 1    B  24.0
# 2    C  22.0
# 3    D   NaN
# 4    E  25.0

# %%
df.isna().sum()
# Out:
# name    0
# age     1
# dtype: int64

# %%
df.dropna(axis = 0)
# Out:
#   name   age
# 0    A  23.0
# 1    B  24.0
# 2    C  22.0
# 4    E  25.0

# %%
df.dropna(axis = 1)
# Out:
#   name
# 0    A
# 1    B
# 2    C
# 3    D
# 4    E

# %%
df
# Out:
#   name   age
# 0    A  23.0
# 1    B  24.0
# 2    C  22.0
# 3    D   NaN
# 4    E  25.0

# %%
df.fillna(0)
# Out:
#   name   age
# 0    A  23.0
# 1    B  24.0
# 2    C  22.0
# 3    D   0.0
# 4    E  25.0

# %%
df
# Out:
#   name   age
# 0    A  23.0
# 1    B  24.0
# 2    C  22.0
# 3    D   NaN
# 4    E  25.0

# %%
df["age"].mean()
# Out:
# 23.5

# %%
df["age"].fillna(df["age"].mean())
# Out:
# 0    23.0
# 1    24.0
# 2    22.0
# 3    23.5
# 4    25.0
# Name: age, dtype: float64

# %%
df
# Out:
#   name   age
# 0    A  23.0
# 1    B  24.0
# 2    C  22.0
# 3    D   NaN
# 4    E  25.0

# %%
df.fillna(method = "bfill")
# Out:
#   name   age
# 0    A  23.0
# 1    B  24.0
# 2    C  22.0
# 3    D  25.0
# 4    E  25.0

# %%
df.fillna(method = "ffill")
# Out:
#   name   age
# 0    A  23.0
# 1    B  24.0
# 2    C  22.0
# 3    D  22.0
# 4    E  25.0

# %%
df.dropna(how = "any" , axis = 0 )
# Out:
#   name   age
# 0    A  23.0
# 1    B  24.0
# 2    C  22.0
# 4    E  25.0

# %%
df.dropna(thresh = 2)
# Out:
#   name   age
# 0    A  23.0
# 1    B  24.0
# 2    C  22.0
# 4    E  25.0
